# %% [markdown]
# # CityScholar-Agent ????
#
# > ????????????
# >
# > 1. ??????????
# > 2. ??????????????
# > 3. ?????????????????????
#
# ---
#
# ## 1. ????
#
# ### 1.1 ????
#
# CityScholar-Agent ??????????????????????????????????
# ?????????????????????? -> ???? -> LangChain/LangGraph -> RAG -> ????????
#
# ### 1.2 ????
#
# ???????????????????????????????????????????????
#
# ????????????
#
# - ?????????
# - ??????????????????????????
# - ??????????????????????????
# - ?????????????????????????

# %% [markdown]
# ## 2. ????
#
# ```text
# ?????
# -> ????
# -> ????
# -> ?????? RAG
# -> ?????
# ```
#
# ### ????
#
# | ?? | ?? | ???? | ?????? |
# | --- | --- | --- | --- |
# | ? 1 ? | ????????? | ???? | ?????? |
# | ? 2 ? | ???????? | ????? | ?????? |
# | ? 3 ? | LangChain / LangGraph ????? | ??????? | ???????? |
# | ? 4 ? | ???????? RAG | ???????? | ???????? |
# | ? 5 ? | ???????? | ????????? | ?????? |
#
# ### ????
#
# - ? 1 ????????????????????
# - ? 2 ?????????????????????
# - ? 3 ????????????????
# - ? 4 ?????? embedding?????????? RAG?
# - ? 5 ????????????

# %% [markdown]
# ## 3. ?????????
#
# ### 3.1 ????
#
# - ????????AI ????????
# - ???????????????????
# - ??????????????????????????
# - ????????????????????
#
# ### 3.2 ????
#
# ```text
# ???????
#     -> ????
#         -> ??????
#             -> ????
#             -> ????
#             -> ????
#                 -> PDF ?????
#                 -> ?????
#                 -> ??????
#                 -> ??????????
#                 -> ????? / Markdown ??
#                 -> ???????
# ```
#
# ### 3.3 ????
#
# | ?? | ?? | ?????? |
# | --- | --- | --- |
# | ??? | ?????????? | `app.py` |
# | ??? | ?????????? | `core/agent.py`?`core/prompts.py` |
# | ????? | ??????????????? | `rag/loader.py`?`rag/parser.py`?`rag/splitter.py`?`rag/retriever.py` |
# | ??? | ????????????? | `tools/analyze_tool.py` |
# | ??? | ???????????? | `app.py` |

# %% [markdown]
# ## 4. ???????????
#
# ### ?????
#
# - ?? PDF ??????
# - ?????????????
# - ?????????
# - ????????????
# - ????????
#
# ### ????????
#
# - ???????
# - ???????
# - embedding / ?????
# - ???????????
# - ???????????
# - LangChain / LangGraph ?????
#
# > ??????????? 1 ????
# > ??????? V1??????????

# %% [markdown]
# ## 5. ??????????
#
# ### ? 1 ???????????
#
# - ??????????????????????????
# - ????????????????? demo??????????
# - ?????`app.py`?`core/agent.py`?`core/prompts.py`
# - ?????????????????????
#
# ### ? 2 ??????????
#
# - ??????????????????
# - ???????????????????????????????
# - ?????`tools/compare_tool.py`?`tools/export_tool.py`?`app.py`
# - ?????????????????????
#
# ### ? 3 ??LangChain / LangGraph ?????
#
# - ??????????????????
# - ?????????????????????????
# - ?????`core/state.py`?`core/planner.py`?????????
# - ????????????????????????????
#
# ### ? 4 ??RAG ?????????
#
# - ???????????????????
# - ??????? embedding??????Top-k ????????
# - ?????`rag/embedder.py`?`rag/knowledge_base.py`?`rag/retriever.py`
# - ??????????????? RAG ???
#
# ### ? 5 ??????????
#
# - ????????????????????????????
# - ?????????????????????????
# - ?????`eval/eval_retrieval.py`?`eval/eval_answer.py`
# - ??????????????????????????

# %% [markdown]
# ## 6. ???????????
#
# ```text
# notebooks/
# ?? 00_????.ipynb
# ?? 01_?????????.ipynb
# ?? 02_????????.ipynb
# ?? 03_LangGraph???????.ipynb
# ?? 04_????????RAG.ipynb
# ?? 05_?????.ipynb
# ```
#
# ### ??????????
#
# 1. ????
# 2. ??????
# 3. ???????????
# 4. ??????
# 5. ??????
# 6. ??????
# 7. ?????????
#
# ---
#
# ## 7. ???????
#
# ??????????????
#
# > ????????AI ???????????????????????????
